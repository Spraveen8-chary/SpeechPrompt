# %%
import sys, os
from pathlib import Path

# get project root (one level above "notebooks")
root_dir = Path(os.getcwd()).parent
sys.path.append(str(root_dir))

print("✅ Added project root to sys.path:", root_dir)
# Out:
# ✅ Added project root to sys.path: d:\SpeechPrompt\PromptSpeech

# %%
import sys
print(sys.executable)
# Out:
# d:\SpeechPrompt\PromptSpeech\.venv\Scripts\python.exe

# %%
import numpy as np
x = np.load("data/processed/speech_commands/down/0a2b400e_nohash_0_hubert.npy")
print(x.shape, x[:10])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 2
#       1 import numpy as np
# ----> 2 x = np.load(r"./data/processed/speech_commands/down/0a2b400e_nohash_0_hubert.npy")
#       3 print(x.shape, x[:10])
#
# File d:\SpeechPrompt\PromptSpeech\.venv\lib\site-packages\numpy\lib\_npyio_impl.py:459, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     457     own_fid = False
#     458 else:
# --> 459     fid = stack.enter_context(open(os.fspath(file), "rb"))
#     460     own_fid = True
#     462 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: './data/processed/speech_commands/down/0a2b400e_nohash_0_hubert.npy'
